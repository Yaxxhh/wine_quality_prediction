# %% [markdown]
# # **Wine Quality Prediction**

# %% [markdown]
# ![image.png](https://scopelliti1887.com/wp-content/uploads/2022/03/baccarat-wine-glasses.jpg.webp)

# %% [markdown]
# ## **Importing DataSet:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the CSV file
df = pd.read_csv("C:\\Users\\hp\\Downloads\\WineQualityPredictor-ML-main\\WineQualityPredictor-ML-main\\WineQT.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 0         9.4        5     0
# 1         9.8        5     1
# 2         9.8        5     2
# 3         9.8        6     3
# 4         9.4        5     4
# ...       ...      ...   ...
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597
#
# [1143 rows x 13 columns]

# %%
df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            6.7              0.58         0.08             1.8      0.097
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 15.0                  65.0   0.9959  3.28       0.54
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# 2      9.8        5   2
# 3      9.8        6   3
# 4      9.4        5   4
# 5      9.4        5   5
# 6      9.4        5   6
# 7     10.0        7   7
# 8      9.5        7   8
# 9      9.2        5  10

# %%
df.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1133            6.7             0.320         0.44             2.4      0.061
# 1134            7.5             0.310         0.41             2.4      0.065
# 1135            5.8             0.610         0.11             1.8      0.066
# 1136            6.3             0.550         0.15             1.8      0.077
# 1137            5.4             0.740         0.09             1.7      0.089
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1133                 24.0                  34.0  0.99484  3.29       0.80
# 1134                 34.0                  60.0  0.99492  3.34       0.85
# 1135                 18.0                  28.0  0.99483  3.55       0.66
# 1136                 26.0                  35.0  0.99314  3.32       0.82
# 1137                 16.0                  26.0  0.99402  3.67       0.56
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 1133     11.6        7  1584
# 1134     11.4        6  1586
# 1135     10.9        6  1587
# 1136     11.6        6  1590
# 1137     11.6        6  1591
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Id                        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df.shape
# Out:
# (1143, 13)

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             21.000000     0.995570
# 50%       0.079000            13.000000             37.000000     0.996680
# 75%       0.090000            21.000000             61.000000     0.997845
# max       0.611000            68.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality           Id
# count  1143.000000  1143.000000  1143.000000  1143.000000  1143.000000
# mean      3.311015     0.657708    10.442111     5.657043   804.969379
# std       0.156664     0.170399     1.082196     0.805824   463.997116
# min       2.740000     0.330000     8.400000     3.000000     0.000000
# 25%       3.205000     0.550000     9.500000     5.000000   411.000000
# 50%       3.310000     0.620000    10.200000     6.000000   794.000000
# 75%       3.400000     0.730000    11.100000     6.000000  1209.500000
# max       4.010000     2.000000    14.900000     8.000000  1597.000000

# %%
df.describe(include='all')
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             21.000000     0.995570
# 50%       0.079000            13.000000             37.000000     0.996680
# 75%       0.090000            21.000000             61.000000     0.997845
# max       0.611000            68.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality           Id
# count  1143.000000  1143.000000  1143.000000  1143.000000  1143.000000
# mean      3.311015     0.657708    10.442111     5.657043   804.969379
# std       0.156664     0.170399     1.082196     0.805824   463.997116
# min       2.740000     0.330000     8.400000     3.000000     0.000000
# 25%       3.205000     0.550000     9.500000     5.000000   411.000000
# 50%       3.310000     0.620000    10.200000     6.000000   794.000000
# 75%       3.400000     0.730000    11.100000     6.000000  1209.500000
# max       4.010000     2.000000    14.900000     8.000000  1597.000000

# %%
df.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1138          False             False        False           False      False
# 1139          False             False        False           False      False
# 1140          False             False        False           False      False
# 1141          False             False        False           False      False
# 1142          False             False        False           False      False
#
#       free sulfur dioxide  total sulfur dioxide  density     pH  sulphates  \
# 0                   False                 False    False  False      False
# 1                   False                 False    False  False      False
# 2                   False                 False    False  False      False
# 3                   False                 False    False  False      False
# 4                   False                 False    False  False      False
# ...                   ...                   ...      ...    ...        ...
# 1138                False                 False    False  False      False
# 1139                False                 False    False  False      False
# 1140                False                 False    False  False      False
# 1141                False                 False    False  False      False
# 1142                False                 False    False  False      False
#
#       alcohol  quality     Id
# 0       False    False  False
# 1       False    False  False
# 2       False    False  False
# 3       False    False  False
# 4       False    False  False
# ...       ...      ...    ...
# 1138    False    False  False
# 1139    False    False  False
# 1140    False    False  False
# 1141    False    False  False
# 1142    False    False  False
#
# [1143 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.450000          0.897500     0.211667        2.666667
# 4             7.809091          0.700000     0.165758        2.566667
# 5             8.161077          0.585280     0.240124        2.540476
# 6             8.317749          0.504957     0.263680        2.444805
# 7             8.851049          0.393671     0.386573        2.760140
# 8             8.806250          0.410000     0.432500        2.643750
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.105333             8.166667             24.500000  0.997682
# 4         0.094788            14.848485             40.606061  0.996669
# 5         0.091770            16.612836             55.299172  0.997073
# 6         0.085281            15.215368             39.941558  0.996610
# 7         0.075217            14.538462             37.489510  0.996071
# 8         0.070187            11.062500             29.375000  0.995553
#
#                pH  sulphates    alcohol           Id
# quality
# 3        3.361667   0.550000   9.691667  1121.166667
# 4        3.391212   0.637879  10.260606   692.848485
# 5        3.302091   0.613375   9.902277   753.925466
# 6        3.323788   0.676537  10.655339   854.625541
# 7        3.287133   0.743566  11.482634   830.349650
# 8        3.240625   0.766250  11.937500   797.875000

# %% [markdown]
# ## **Exploratory Data Analysis (EDA):**

# %% [markdown]
# ### 1. Summary Statistics:
#
#  Function used:`DataFrame.describe`

# %%
# Display summary stats for all numerical columns:

summary_stats=df.describe(include='all')
print(summary_stats)
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             21.000000     0.995570
# 50%       0.079000            13.000000             37.000000     0.996680
# 75%       0.090000            21.000000             61.000000     0.997845
# max       0.611000            68.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality           Id
# count  1143.000000  1143.000000  1143.000000  1143.000000  1143.000000
# mean      3.311015     0.657708    10.442111     5.657043   804.969379
# std       0.156664     0.170399     1.082196     0.805824   463.997116
# min       2.740000     0.330000     8.400000     3.000000     0.000000
# 25%       3.205000     0.550000     9.500000     5.000000   411.000000
# 50%       3.310000     0.620000    10.200000     6.000000   794.000000
# 75%       3.400000     0.730000    11.100000     6.000000  1209.500000
# max       4.010000     2.000000    14.900000     8.000000  1597.000000

# %% [markdown]
# ### 2. Histograms:
#
# Function used: `seaborn.histplot()`

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='density', kde=True, color='blue')
plt.xlabel('Density', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Distribution of Density', fontsize=14)
plt.show()

# %% [markdown]
# ## Decision Tree Model

# %%
X=df.drop(columns='quality',axis=1)
y=df['quality']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# #### Data Modeling:

# %%
from sklearn.tree import DecisionTreeRegressor
model= DecisionTreeRegressor()
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.metrics import mean_squared_error, r2_score

decision_tree_model = DecisionTreeRegressor()
decision_tree_model.fit(X_train, y_train)
decision_tree_predictions = decision_tree_model.predict(X_test)

# Calculate MSE and R-squared for Decision Tree Regressor
dt_mse = mean_squared_error(y_test, decision_tree_predictions)
dt_r2 = r2_score(y_test, decision_tree_predictions)

# %% [markdown]
# #### Model Predictions:

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([5., 7., 7., 7., 6., 5., 6., 6., 6., 8., 4., 7., 6., 6., 6., 6., 6.,
#        5., 6., 5., 3., 5., 5., 5., 7., 7., 6., 6., 6., 6., 5., 5., 6., 6.,
#        4., 5., 5., 6., 5., 6., 5., 5., 8., 7., 6., 6., 5., 7., 5., 6., 6.,
#        7., 5., 6., 6., 5., 6., 5., 5., 6., 6., 7., 6., 6., 4., 5., 5., 7.,
#        6., 5., 5., 5., 5., 7., 5., 5., 6., 5., 5., 5., 5., 6., 5., 7., 7.,
#        7., 5., 5., 5., 6., 7., 5., 6., 7., 6., 5., 7., 5., 8., 7., 5., 6.,
#        7., 5., 5., 5., 5., 7., 7., 7., 6., 4., 3., 5., 5., 6., 4., 5., 5.,
#        5., 6., 6., 5., 5., 5., 5., 7., 6., 6., 5., 5., 5., 6., 6., 5., 5.,
#        8., 5., 8., 6., 5., 7., 6., 5., 6., 6., 6., 6., 5., 5., 7., 7., 6.,
#        6., 5., 6., 5., 6., 5., 5., 6., 6., 6., 6., 6., 6., 5., 5., 5., 6.,
#        5., 6., 5., 5., 5., 6., 7., 7., 6., 5., 7., 5., 6., 5., 5., 6., 6.,
#        6., 5., 5., 3., 7., 7., 4., 7., 5., 5., 5., 6., 5., 5., 6., 5., 5.,
#        6., 5., 6., 5., 5., 5., 5., 6., 5., 5., 5., 6., 5., 7., 7., 6., 4.,
#        6., 5., 7., 6., 5., 6., 8., 5., 6., 6., 6., 4., 5., 6., 5., 5., 5.,
#        3., 5., 6., 6., 4., 5., 6., 4., 7., 7., 5., 5., 5., 6., 4., 6., 6.,
#        6., 8., 6., 6., 7., 7., 5., 5., 6., 4., 6., 5., 7., 5., 5., 5., 5.,
#        6., 6., 5., 6., 7., 5., 6., 6., 5., 6., 6., 6., 6., 4.])

# %% [markdown]
# #### Decision Tree:

# %%
from sklearn import tree
plt.figure(figsize=(20,20))
tree.plot_tree(model, filled=True)
# Out:
# [Text(0.592171052631579, 0.96875, 'X[10] <= 10.525\nsquared_error = 0.641\nsamples = 857\nvalue = 5.664'),
#  Text(0.3547697368421053, 0.90625, 'X[9] <= 0.645\nsquared_error = 0.421\nsamples = 525\nvalue = 5.392'),
#  Text(0.24375, 0.84375, 'X[1] <= 0.873\nsquared_error = 0.298\nsamples = 359\nvalue = 5.259'),
#  Text(0.1611842105263158, 0.78125, 'X[10] <= 9.75\nsquared_error = 0.265\nsamples = 340\nvalue = 5.291'),
#  Text(0.06697368421052631, 0.71875, 'X[10] <= 8.7\nsquared_error = 0.209\nsamples = 202\nvalue = 5.183'),
#  Text(0.06276315789473684, 0.65625, 'squared_error = 0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.0711842105263158, 0.65625, 'X[9] <= 0.575\nsquared_error = 0.186\nsamples = 201\nvalue = 5.194'),
#  Text(0.02526315789473684, 0.59375, 'X[8] <= 3.54\nsquared_error = 0.118\nsamples = 119\nvalue = 5.092'),
#  Text(0.021052631578947368, 0.53125, 'X[1] <= 0.83\nsquared_error = 0.105\nsamples = 117\nvalue = 5.077'),
#  Text(0.016842105263157894, 0.46875, 'X[10] <= 9.05\nsquared_error = 0.099\nsamples = 116\nvalue = 5.069'),
#  Text(0.01263157894736842, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.021052631578947368, 0.40625, 'X[10] <= 9.45\nsquared_error = 0.092\nsamples = 115\nvalue = 5.061'),
#  Text(0.01263157894736842, 0.34375, 'X[11] <= 60.5\nsquared_error = 0.019\nsamples = 51\nvalue = 4.98'),
#  Text(0.008421052631578947, 0.28125, 'X[8] <= 3.3\nsquared_error = 0.16\nsamples = 5\nvalue = 4.8'),
#  Text(0.004210526315789474, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.01263157894736842, 0.21875, 'squared_error = 0.0\nsamples = 4\nvalue = 5.0'),
#  Text(0.016842105263157894, 0.28125, 'squared_error = 0.0\nsamples = 46\nvalue = 5.0'),
#  Text(0.029473684210526315, 0.34375, 'X[11] <= 53.5\nsquared_error = 0.141\nsamples = 64\nvalue = 5.125'),
#  Text(0.02526315789473684, 0.28125, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.03368421052631579, 0.28125, 'X[11] <= 1253.0\nsquared_error = 0.131\nsamples = 63\nvalue = 5.111'),
#  Text(0.02526315789473684, 0.21875, 'X[11] <= 1173.0\nsquared_error = 0.096\nsamples = 50\nvalue = 5.06'),
#  Text(0.021052631578947368, 0.15625, 'X[1] <= 0.665\nsquared_error = 0.075\nsamples = 49\nvalue = 5.082'),
#  Text(0.01263157894736842, 0.09375, 'X[2] <= 0.02\nsquared_error = 0.025\nsamples = 39\nvalue = 5.026'),
#  Text(0.008421052631578947, 0.03125, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.016842105263157894, 0.03125, 'squared_error = 0.0\nsamples = 38\nvalue = 5.0'),
#  Text(0.029473684210526315, 0.09375, 'X[0] <= 8.55\nsquared_error = 0.21\nsamples = 10\nvalue = 5.3'),
#  Text(0.02526315789473684, 0.03125, 'squared_error = 0.0\nsamples = 7\nvalue = 5.0'),
#  Text(0.03368421052631579, 0.03125, 'squared_error = 0.0\nsamples = 3\nvalue = 6.0'),
#  Text(0.029473684210526315, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.042105263157894736, 0.21875, 'X[11] <= 1332.5\nsquared_error = 0.213\nsamples = 13\nvalue = 5.308'),
#  Text(0.037894736842105266, 0.15625, 'squared_error = 0.0\nsamples = 3\nvalue = 6.0'),
#  Text(0.04631578947368421, 0.15625, 'X[1] <= 0.78\nsquared_error = 0.09\nsamples = 10\nvalue = 5.1'),
#  Text(0.042105263157894736, 0.09375, 'squared_error = 0.0\nsamples = 9\nvalue = 5.0'),
#  Text(0.05052631578947368, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.02526315789473684, 0.46875, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.029473684210526315, 0.53125, 'squared_error = 0.0\nsamples = 2\nvalue = 6.0'),
#  Text(0.11710526315789474, 0.59375, 'X[4] <= 0.113\nsquared_error = 0.249\nsamples = 82\nvalue = 5.341'),
#  Text(0.10157894736842105, 0.53125, 'X[1] <= 0.65\nsquared_error = 0.234\nsamples = 75\nvalue = 5.293'),
#  Text(0.08315789473684211, 0.46875, 'X[4] <= 0.078\nsquared_error = 0.224\nsamples = 68\nvalue = 5.338'),
#  Text(0.05894736842105263, 0.40625, 'X[4] <= 0.06\nsquared_error = 0.139\nsamples = 30\nvalue = 5.167'),
#  Text(0.05473684210526316, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.06315789473684211, 0.34375, 'X[4] <= 0.072\nsquared_error = 0.119\nsamples = 29\nvalue = 5.138'),
#  Text(0.05894736842105263, 0.28125, 'squared_error = 0.0\nsamples = 13\nvalue = 5.0'),
#  Text(0.06736842105263158, 0.28125, 'X[7] <= 0.997\nsquared_error = 0.188\nsamples = 16\nvalue = 5.25'),
#  Text(0.05894736842105263, 0.21875, 'X[5] <= 24.0\nsquared_error = 0.24\nsamples = 5\nvalue = 5.6'),
#  Text(0.05473684210526316, 0.15625, 'squared_error = 0.0\nsamples = 2\nvalue = 6.0'),
#  Text(0.06315789473684211, 0.15625, 'X[7] <= 0.997\nsquared_error = 0.222\nsamples = 3\nvalue = 5.333'),
#  Text(0.05894736842105263, 0.09375, 'squared_error = 0.0\nsamples = 2\nvalue = 5.0'),
#  Text(0.06736842105263158, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.07578947368421053, 0.21875, 'X[2] <= 0.185\nsquared_error = 0.083\nsamples = 11\nvalue = 5.091'),
#  Text(0.07157894736842105, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.08, 0.15625, 'squared_error = 0.0\nsamples = 10\nvalue = 5.0'),
#  Text(0.10736842105263159, 0.40625, 'X[7] <= 0.998\nsquared_error = 0.249\nsamples = 38\nvalue = 5.474'),
#  Text(0.09263157894736843, 0.34375, 'X[7] <= 0.996\nsquared_error = 0.204\nsamples = 21\nvalue = 5.714'),
#  Text(0.08842105263157894, 0.28125, 'squared_error = 0.0\nsamples = 3\nvalue = 5.0'),
#  Text(0.0968421052631579, 0.28125, 'X[6] <= 95.5\nsquared_error = 0.139\nsamples = 18\nvalue = 5.833'),
#  Text(0.09263157894736843, 0.21875, 'X[2] <= 0.335\nsquared_error = 0.059\nsamples = 16\nvalue = 5.938'),
#  Text(0.08842105263157894, 0.15625, 'squared_error = 0.0\nsamples = 14\nvalue = 6.0'),
#  Text(0.0968421052631579, 0.15625, 'X[11] <= 178.5\nsquared_error = 0.25\nsamples = 2\nvalue = 5.5'),
#  Text(0.09263157894736843, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.10105263157894737, 0.09375, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.10105263157894737, 0.21875, 'squared_error = 0.0\nsamples = 2\nvalue = 5.0'),
#  Text(0.12210526315789473, 0.34375, 'X[11] <= 412.0\nsquared_error = 0.145\nsamples = 17\nvalue = 5.176'),
#  Text(0.11368421052631579, 0.28125, 'X[1] <= 0.415\nsquared_error = 0.222\nsamples = 3\nvalue = 5.667'),
#  Text(0.10947368421052632, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.11789473684210526, 0.21875, 'squared_error = 0.0\nsamples = 2\nvalue = 6.0'),
#  Text(0.13052631578947368, 0.28125, 'X[2] <= 0.14\nsquared_error = 0.066\nsamples = 14\nvalue = 5.071'),
#  Text(0.12631578947368421, 0.21875, 'X[5] <= 19.0\nsquared_error = 0.25\nsamples = 2\nvalue = 5.5'),
#  Text(0.12210526315789473, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.13052631578947368, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.13473684210526315, 0.21875, 'squared_error = 0.0\nsamples = 12\nvalue = 5.0'),
#  Text(0.12, 0.46875, 'X[8] <= 3.205\nsquared_error = 0.122\nsamples = 7\nvalue = 4.857'),
#  Text(0.11578947368421053, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.12421052631578948, 0.40625, 'squared_error = 0.0\nsamples = 6\nvalue = 5.0'),
#  Text(0.13263157894736843, 0.53125, 'X[5] <= 23.5\nsquared_error = 0.122\nsamples = 7\nvalue = 5.857'),
#  Text(0.12842105263157894, 0.46875, 'squared_error = 0.0\nsamples = 6\nvalue = 6.0'),
#  Text(0.1368421052631579, 0.46875, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.2553947368421053, 0.71875, 'X[11] <= 1380.0\nsquared_error = 0.305\nsamples = 138\nvalue = 5.449'),
#  Text(0.21394736842105264, 0.65625, 'X[1] <= 0.655\nsquared_error = 0.302\nsamples = 113\nvalue = 5.531'),
#  Text(0.17105263157894737, 0.59375, 'X[2] <= 0.025\nsquared_error = 0.303\nsamples = 86\nvalue = 5.628'),
#  Text(0.14947368421052631, 0.53125, 'X[8] <= 3.47\nsquared_error = 0.29\nsamples = 10\nvalue = 6.1'),
#  Text(0.14526315789473684, 0.46875, 'X[11] <= 1069.5\nsquared_error = 0.173\nsamples = 9\nvalue = 6.222'),
#  Text(0.14105263157894737, 0.40625, 'X[0] <= 7.75\nsquared_error = 0.222\nsamples = 3\nvalue = 6.667'),
#  Text(0.1368421052631579, 0.34375, 'squared_error = 0.0\nsamples = 2\nvalue = 7.0'),
#  Text(0.14526315789473684, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.14947368421052631, 0.40625, 'squared_error = 0.0\nsamples = 6\nvalue = 6.0'),
#  Text(0.15368421052631578, 0.46875, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.19263157894736843, 0.53125, 'X[9] <= 0.545\nsquared_error = 0.272\nsamples = 76\nvalue = 5.566'),
#  Text(0.1726315789473684, 0.46875, 'X[8] <= 3.335\nsquared_error = 0.299\nsamples = 30\nvalue = 5.367'),
#  Text(0.16210526315789472, 0.40625, 'X[2] <= 0.245\nsquared_error = 0.248\nsamples = 22\nvalue = 5.545'),
#  Text(0.15368421052631578, 0.34375, 'X[3] <= 2.45\nsquared_error = 0.109\nsamples = 8\nvalue = 5.875'),
#  Text(0.14947368421052631, 0.28125, 'squared_error = 0.0\nsamples = 7\nvalue = 6.0'),
#  Text(0.15789473684210525, 0.28125, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.1705263157894737, 0.34375, 'X[2] <= 0.34\nsquared_error = 0.23\nsamples = 14\nvalue = 5.357'),
#  Text(0.16631578947368422, 0.28125, 'squared_error = 0.0\nsamples = 8\nvalue = 5.0'),
#  Text(0.17473684210526316, 0.28125, 'X[0] <= 10.85\nsquared_error = 0.139\nsamples = 6\nvalue = 5.833'),
#  Text(0.1705263157894737, 0.21875, 'squared_error = 0.0\nsamples = 5\nvalue = 6.0'),
#  Text(0.17894736842105263, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.1831578947368421, 0.40625, 'X[7] <= 0.997\nsquared_error = 0.109\nsamples = 8\nvalue = 4.875'),
#  Text(0.17894736842105263, 0.34375, 'squared_error = 0.0\nsamples = 7\nvalue = 5.0'),
#  Text(0.18736842105263157, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.21263157894736842, 0.46875, 'X[2] <= 0.315\nsquared_error = 0.212\nsamples = 46\nvalue = 5.696'),
#  Text(0.20421052631578948, 0.40625, 'X[4] <= 0.082\nsquared_error = 0.173\nsamples = 36\nvalue = 5.778'),
#  Text(0.2, 0.34375, 'X[9] <= 0.585\nsquared_error = 0.24\nsamples = 20\nvalue = 5.6'),
#  Text(0.19157894736842104, 0.28125, 'X[1] <= 0.47\nsquared_error = 0.109\nsamples = 8\nvalue = 5.875'),
#  Text(0.18736842105263157, 0.21875, 'X[11] <= 471.0\nsquared_error = 0.25\nsamples = 2\nvalue = 5.5'),
#  Text(0.1831578947368421, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.19157894736842104, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.1957894736842105, 0.21875, 'squared_error = 0.0\nsamples = 6\nvalue = 6.0'),
#  Text(0.20842105263157895, 0.28125, 'X[7] <= 0.996\nsquared_error = 0.243\nsamples = 12\nvalue = 5.417'),
#  Text(0.20421052631578948, 0.21875, 'squared_error = 0.0\nsamples = 4\nvalue = 6.0'),
#  Text(0.21263157894736842, 0.21875, 'X[8] <= 3.55\nsquared_error = 0.109\nsamples = 8\nvalue = 5.125'),
#  Text(0.20842105263157895, 0.15625, 'squared_error = 0.0\nsamples = 7\nvalue = 5.0'),
#  Text(0.2168421052631579, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.20842105263157895, 0.34375, 'squared_error = 0.0\nsamples = 16\nvalue = 6.0'),
#  Text(0.22105263157894736, 0.40625, 'X[6] <= 59.0\nsquared_error = 0.24\nsamples = 10\nvalue = 5.4'),
#  Text(0.2168421052631579, 0.34375, 'squared_error = 0.0\nsamples = 4\nvalue = 5.0'),
#  Text(0.22526315789473683, 0.34375, 'X[6] <= 65.5\nsquared_error = 0.222\nsamples = 6\nvalue = 5.667'),
#  Text(0.22105263157894736, 0.28125, 'squared_error = 0.0\nsamples = 4\nvalue = 6.0'),
#  Text(0.2294736842105263, 0.28125, 'squared_error = 0.0\nsamples = 2\nvalue = 5.0'),
#  Text(0.25684210526315787, 0.59375, 'X[2] <= 0.28\nsquared_error = 0.173\nsamples = 27\nvalue = 5.222'),
#  Text(0.24210526315789474, 0.53125, 'X[11] <= 359.5\nsquared_error = 0.118\nsamples = 22\nvalue = 5.136'),
#  Text(0.2336842105263158, 0.46875, 'X[11] <= 144.5\nsquared_error = 0.24\nsamples = 5\nvalue = 5.4'),
#  Text(0.2294736842105263, 0.40625, 'squared_error = 0.0\nsamples = 3\nvalue = 5.0'),
#  Text(0.23789473684210527, 0.40625, 'squared_error = 0.0\nsamples = 2\nvalue = 6.0'),
#  Text(0.2505263157894737, 0.46875, 'X[3] <= 1.65\nsquared_error = 0.055\nsamples = 17\nvalue = 5.059'),
#  Text(0.2463157894736842, 0.40625, 'X[8] <= 3.29\nsquared_error = 0.25\nsamples = 2\nvalue = 5.5'),
#  Text(0.24210526315789474, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.2505263157894737, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.25473684210526315, 0.40625, 'squared_error = 0.0\nsamples = 15\nvalue = 5.0'),
#  Text(0.27157894736842103, 0.53125, 'X[9] <= 0.54\nsquared_error = 0.24\nsamples = 5\nvalue = 5.6'),
#  Text(0.2673684210526316, 0.46875, 'X[2] <= 0.345\nsquared_error = 0.222\nsamples = 3\nvalue = 5.333'),
#  Text(0.2631578947368421, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.27157894736842103, 0.40625, 'squared_error = 0.0\nsamples = 2\nvalue = 5.0'),
#  Text(0.27578947368421053, 0.46875, 'squared_error = 0.0\nsamples = 2\nvalue = 6.0'),
#  Text(0.2968421052631579, 0.65625, 'X[8] <= 3.52\nsquared_error = 0.154\nsamples = 25\nvalue = 5.08'),
#  Text(0.2926315789473684, 0.59375, 'X[4] <= 0.069\nsquared_error = 0.109\nsamples = 24\nvalue = 5.125'),
#  Text(0.28842105263157897, 0.53125, 'X[10] <= 10.25\nsquared_error = 0.25\nsamples = 6\nvalue = 5.5'),
#  Text(0.28421052631578947, 0.46875, 'squared_error = 0.0\nsamples = 3\nvalue = 6.0'),
#  Text(0.2926315789473684, 0.46875, 'squared_error = 0.0\nsamples = 3\nvalue = 5.0'),
#  Text(0.2968421052631579, 0.53125, 'squared_error = 0.0\nsamples = 18\nvalue = 5.0'),
#  Text(0.30105263157894735, 0.59375, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.3263157894736842, 0.78125, 'X[2] <= 0.055\nsquared_error = 0.532\nsamples = 19\nvalue = 4.684'),
#  Text(0.3178947368421053, 0.71875, 'X[2] <= 0.045\nsquared_error = 0.609\nsamples = 8\nvalue = 4.125'),
#  Text(0.3136842105263158, 0.65625, 'X[11] <= 518.0\nsquared_error = 0.25\nsamples = 6\nvalue = 4.5'),
#  Text(0.3094736842105263, 0.59375, 'X[8] <= 3.275\nsquared_error = 0.188\nsamples = 4\nvalue = 4.25'),
#  Text(0.30526315789473685, 0.53125, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.3136842105263158, 0.53125, 'squared_error = 0.0\nsamples = 3\nvalue = 4.0'),
#  Text(0.3178947368421053, 0.59375, 'squared_error = 0.0\nsamples = 2\nvalue = 5.0'),
#  Text(0.32210526315789473, 0.65625, 'squared_error = 0.0\nsamples = 2\nvalue = 3.0'),
#  Text(0.33473684210526317, 0.71875, 'X[4] <= 0.069\nsquared_error = 0.083\nsamples = 11\nvalue = 5.091'),
#  Text(0.33052631578947367, 0.65625, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.3389473684210526, 0.65625, 'squared_error = 0.0\nsamples = 10\nvalue = 5.0'),
#  Text(0.46578947368421053, 0.84375, 'X[6] <= 59.5\nsquared_error = 0.567\nsamples = 166\nvalue = 5.681'),
#  Text(0.4284210526315789, 0.78125, 'X[0] <= 11.55\nsquared_error = 0.528\nsamples = 118\nvalue = 5.881'),
#  Text(0.3831578947368421, 0.71875, 'X[4] <= 0.062\nsquared_error = 0.451\nsamples = 103\nvalue = 5.767'),
#  Text(0.3473684210526316, 0.65625, 'X[5] <= 4.0\nsquared_error = 0.484\nsamples = 8\nvalue = 6.625'),
#  Text(0.3431578947368421, 0.59375, 'squared_error = 0.0\nsamples = 1\nvalue = 8.0'),
#  Text(0.35157894736842105, 0.59375, 'X[7] <= 0.997\nsquared_error = 0.245\nsamples = 7\nvalue = 6.429'),
#  Text(0.3473684210526316, 0.53125, 'squared_error = 0.0\nsamples = 4\nvalue = 6.0'),
#  Text(0.35578947368421054, 0.53125, 'squared_error = 0.0\nsamples = 3\nvalue = 7.0'),
#  Text(0.4189473684210526, 0.65625, 'X[1] <= 0.545\nsquared_error = 0.38\nsamples = 95\nvalue = 5.695'),
#  Text(0.3873684210526316, 0.59375, 'X[10] <= 9.65\nsquared_error = 0.335\nsamples = 54\nvalue = 5.87'),
#  Text(0.3642105263157895, 0.53125, 'X[4] <= 0.084\nsquared_error = 0.232\nsamples = 30\nvalue = 5.633'),
#  Text(0.35578947368421054, 0.46875, 'X[11] <= 265.5\nsquared_error = 0.139\nsamples = 18\nvalue = 5.833'),
#  Text(0.35157894736842105, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.36, 0.40625, 'X[7] <= 1.002\nsquared_error = 0.104\nsamples = 17\nvalue = 5.882'),
#  Text(0.35578947368421054, 0.34375, 'X[2] <= 0.565\nsquared_error = 0.059\nsamples = 16\nvalue = 5.938'),
#  Text(0.35157894736842105, 0.28125, 'squared_error = 0.0\nsamples = 15\nvalue = 6.0'),
#  Text(0.36, 0.28125, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.3642105263157895, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.3726315789473684, 0.46875, 'X[9] <= 0.76\nsquared_error = 0.222\nsamples = 12\nvalue = 5.333'),
#  Text(0.3684210526315789, 0.40625, 'squared_error = 0.0\nsamples = 2\nvalue = 6.0'),
#  Text(0.37684210526315787, 0.40625, 'X[5] <= 2.5\nsquared_error = 0.16\nsamples = 10\nvalue = 5.2'),
#  Text(0.3726315789473684, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.38105263157894737, 0.34375, 'X[10] <= 9.15\nsquared_error = 0.099\nsamples = 9\nvalue = 5.111'),
#  Text(0.37684210526315787, 0.28125, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.38526315789473686, 0.28125, 'squared_error = 0.0\nsamples = 8\nvalue = 5.0'),
#  Text(0.4105263157894737, 0.53125, 'X[0] <= 9.0\nsquared_error = 0.306\nsamples = 24\nvalue = 6.167'),
#  Text(0.39789473684210525, 0.46875, 'X[1] <= 0.215\nsquared_error = 0.43\nsamples = 11\nvalue = 6.455'),
#  Text(0.3936842105263158, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.40210526315789474, 0.40625, 'X[5] <= 15.5\nsquared_error = 0.24\nsamples = 10\nvalue = 6.6'),
#  Text(0.39789473684210525, 0.34375, 'X[1] <= 0.45\nsquared_error = 0.122\nsamples = 7\nvalue = 6.857'),
#  Text(0.3936842105263158, 0.28125, 'squared_error = 0.0\nsamples = 6\nvalue = 7.0'),
#  Text(0.40210526315789474, 0.28125, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.4063157894736842, 0.34375, 'squared_error = 0.0\nsamples = 3\nvalue = 6.0'),
#  Text(0.4231578947368421, 0.46875, 'X[10] <= 9.75\nsquared_error = 0.071\nsamples = 13\nvalue = 5.923'),
#  Text(0.4189473684210526, 0.40625, 'X[6] <= 31.0\nsquared_error = 0.25\nsamples = 2\nvalue = 5.5'),
#  Text(0.4147368421052632, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.4231578947368421, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.42736842105263156, 0.40625, 'squared_error = 0.0\nsamples = 11\nvalue = 6.0'),
#  Text(0.45052631578947366, 0.59375, 'X[7] <= 0.997\nsquared_error = 0.346\nsamples = 41\nvalue = 5.463'),
#  Text(0.4357894736842105, 0.53125, 'X[5] <= 3.5\nsquared_error = 0.381\nsamples = 17\nvalue = 5.176'),
#  Text(0.43157894736842106, 0.46875, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.44, 0.46875, 'X[3] <= 1.45\nsquared_error = 0.184\nsamples = 16\nvalue = 5.062'),
#  Text(0.4357894736842105, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.4442105263157895, 0.40625, 'X[4] <= 0.069\nsquared_error = 0.116\nsamples = 15\nvalue = 5.133'),
#  Text(0.44, 0.34375, 'X[3] <= 1.85\nsquared_error = 0.24\nsamples = 5\nvalue = 5.4'),
#  Text(0.4357894736842105, 0.28125, 'squared_error = 0.0\nsamples = 3\nvalue = 5.0'),
#  Text(0.4442105263157895, 0.28125, 'squared_error = 0.0\nsamples = 2\nvalue = 6.0'),
#  Text(0.44842105263157894, 0.34375, 'squared_error = 0.0\nsamples = 10\nvalue = 5.0'),
#  Text(0.4652631578947368, 0.53125, 'X[11] <= 910.0\nsquared_error = 0.222\nsamples = 24\nvalue = 5.667'),
#  Text(0.4568421052631579, 0.46875, 'X[10] <= 9.2\nsquared_error = 0.166\nsamples = 19\nvalue = 5.789'),
#  Text(0.45263157894736844, 0.40625, 'squared_error = 0.0\nsamples = 2\nvalue = 5.0'),
#  Text(0.4610526315789474, 0.40625, 'X[5] <= 26.5\nsquared_error = 0.104\nsamples = 17\nvalue = 5.882'),
#  Text(0.4568421052631579, 0.34375, 'X[1] <= 0.695\nsquared_error = 0.059\nsamples = 16\nvalue = 5.938'),
#  Text(0.45263157894736844, 0.28125, 'squared_error = 0.0\nsamples = 13\nvalue = 6.0'),
#  Text(0.4610526315789474, 0.28125, 'X[0] <= 8.65\nsquared_error = 0.222\nsamples = 3\nvalue = 5.667'),
#  Text(0.4568421052631579, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.4652631578947368, 0.21875, 'squared_error = 0.0\nsamples = 2\nvalue = 6.0'),
#  Text(0.4652631578947368, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.47368421052631576, 0.46875, 'X[5] <= 3.5\nsquared_error = 0.16\nsamples = 5\nvalue = 5.2'),
#  Text(0.4694736842105263, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.47789473684210526, 0.40625, 'squared_error = 0.0\nsamples = 4\nvalue = 5.0'),
#  Text(0.47368421052631576, 0.71875, 'X[4] <= 0.072\nsquared_error = 0.356\nsamples = 15\nvalue = 6.667'),
#  Text(0.4694736842105263, 0.65625, 'squared_error = 0.0\nsamples = 1\nvalue = 8.0'),
#  Text(0.47789473684210526, 0.65625, 'X[5] <= 6.5\nsquared_error = 0.245\nsamples = 14\nvalue = 6.571'),
#  Text(0.47368421052631576, 0.59375, 'squared_error = 0.0\nsamples = 4\nvalue = 6.0'),
#  Text(0.48210526315789476, 0.59375, 'X[6] <= 21.5\nsquared_error = 0.16\nsamples = 10\nvalue = 6.8'),
#  Text(0.47789473684210526, 0.53125, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.4863157894736842, 0.53125, 'X[6] <= 47.5\nsquared_error = 0.099\nsamples = 9\nvalue = 6.889'),
#  Text(0.48210526315789476, 0.46875, 'squared_error = 0.0\nsamples = 8\nvalue = 7.0'),
#  Text(0.4905263157894737, 0.46875, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.5031578947368421, 0.78125, 'X[0] <= 6.95\nsquared_error = 0.319\nsamples = 48\nvalue = 5.188'),
#  Text(0.49473684210526314, 0.71875, 'X[3] <= 1.75\nsquared_error = 0.139\nsamples = 6\nvalue = 5.833'),
#  Text(0.4905263157894737, 0.65625, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.49894736842105264, 0.65625, 'squared_error = 0.0\nsamples = 5\nvalue = 6.0'),
#  Text(0.511578947368421, 0.71875, 'X[5] <= 50.0\nsquared_error = 0.277\nsamples = 42\nvalue = 5.095'),
#  Text(0.5073684210526316, 0.65625, 'X[9] <= 1.32\nsquared_error = 0.248\nsamples = 40\nvalue = 5.05'),
#  Text(0.49894736842105264, 0.59375, 'X[1] <= 0.365\nsquared_error = 0.146\nsamples = 34\nvalue = 4.971'),
#  Text(0.49473684210526314, 0.53125, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.5031578947368421, 0.53125, 'X[8] <= 3.56\nsquared_error = 0.118\nsamples = 33\nvalue = 4.939'),
#  Text(0.49894736842105264, 0.46875, 'X[3] <= 1.55\nsquared_error = 0.093\nsamples = 32\nvalue = 4.969'),
#  Text(0.49473684210526314, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.5031578947368421, 0.40625, 'X[9] <= 0.655\nsquared_error = 0.065\nsamples = 31\nvalue = 5.0'),
#  Text(0.49473684210526314, 0.34375, 'X[1] <= 0.395\nsquared_error = 0.222\nsamples = 3\nvalue = 5.333'),
#  Text(0.4905263157894737, 0.28125, 'squared_error = 0.0\nsamples = 2\nvalue = 5.0'),
#  Text(0.49894736842105264, 0.28125, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.511578947368421, 0.34375, 'X[1] <= 0.395\nsquared_error = 0.034\nsamples = 28\nvalue = 4.964'),
#  Text(0.5073684210526316, 0.28125, 'X[2] <= 0.54\nsquared_error = 0.25\nsamples = 2\nvalue = 4.5'),
#  Text(0.5031578947368421, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.511578947368421, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.5157894736842106, 0.28125, 'squared_error = 0.0\nsamples = 26\nvalue = 5.0'),
#  Text(0.5073684210526316, 0.46875, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.5157894736842106, 0.59375, 'X[5] <= 29.5\nsquared_error = 0.583\nsamples = 6\nvalue = 5.5'),
#  Text(0.511578947368421, 0.53125, 'squared_error = 0.0\nsamples = 4\nvalue = 6.0'),
#  Text(0.52, 0.53125, 'X[2] <= 0.65\nsquared_error = 0.25\nsamples = 2\nvalue = 4.5'),
#  Text(0.5157894736842106, 0.46875, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.5242105263157895, 0.46875, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.5157894736842106, 0.65625, 'squared_error = 0.0\nsamples = 2\nvalue = 6.0'),
#  Text(0.8295723684210526, 0.90625, 'X[1] <= 0.595\nsquared_error = 0.687\nsamples = 332\nvalue = 6.093'),
#  Text(0.7075657894736842, 0.84375, 'X[10] <= 11.55\nsquared_error = 0.582\nsamples = 248\nvalue = 6.266'),
#  Text(0.6159210526315789, 0.78125, 'X[9] <= 0.585\nsquared_error = 0.515\nsamples = 135\nvalue = 6.059'),
#  Text(0.5589473684210526, 0.71875, 'X[6] <= 7.5\nsquared_error = 0.48\nsamples = 25\nvalue = 5.6'),
#  Text(0.5547368421052632, 0.65625, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.5631578947368421, 0.65625, 'X[10] <= 11.45\nsquared_error = 0.389\nsamples = 24\nvalue = 5.667'),
#  Text(0.5515789473684211, 0.59375, 'X[11] <= 1061.5\nsquared_error = 0.34\nsamples = 21\nvalue = 5.571'),
#  Text(0.5410526315789473, 0.53125, 'X[7] <= 0.996\nsquared_error = 0.264\nsamples = 11\nvalue = 5.909'),
#  Text(0.5326315789473685, 0.46875, 'X[9] <= 0.5\nsquared_error = 0.109\nsamples = 8\nvalue = 6.125'),
#  Text(0.5284210526315789, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.5368421052631579, 0.40625, 'squared_error = 0.0\nsamples = 7\nvalue = 6.0'),
#  Text(0.5494736842105263, 0.46875, 'X[6] <= 25.5\nsquared_error = 0.222\nsamples = 3\nvalue = 5.333'),
#  Text(0.5452631578947369, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.5536842105263158, 0.40625, 'squared_error = 0.0\nsamples = 2\nvalue = 5.0'),
#  Text(0.5621052631578948, 0.53125, 'X[4] <= 0.091\nsquared_error = 0.16\nsamples = 10\nvalue = 5.2'),
#  Text(0.5578947368421052, 0.46875, 'squared_error = 0.0\nsamples = 8\nvalue = 5.0'),
#  Text(0.5663157894736842, 0.46875, 'squared_error = 0.0\nsamples = 2\nvalue = 6.0'),
#  Text(0.5747368421052632, 0.59375, 'X[5] <= 9.0\nsquared_error = 0.222\nsamples = 3\nvalue = 6.333'),
#  Text(0.5705263157894737, 0.53125, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.5789473684210527, 0.53125, 'squared_error = 0.0\nsamples = 2\nvalue = 6.0'),
#  Text(0.6728947368421052, 0.71875, 'X[1] <= 0.4\nsquared_error = 0.464\nsamples = 110\nvalue = 6.164'),
#  Text(0.63, 0.65625, 'X[6] <= 45.0\nsquared_error = 0.553\nsamples = 55\nvalue = 6.345'),
#  Text(0.6052631578947368, 0.59375, 'X[8] <= 3.255\nsquared_error = 0.448\nsamples = 40\nvalue = 6.55'),
#  Text(0.5873684210526315, 0.53125, 'X[5] <= 8.5\nsquared_error = 0.331\nsamples = 22\nvalue = 6.818'),
#  Text(0.5789473684210527, 0.46875, 'X[7] <= 0.998\nsquared_error = 0.43\nsamples = 11\nvalue = 6.545'),
#  Text(0.5747368421052632, 0.40625, 'X[0] <= 10.6\nsquared_error = 0.438\nsamples = 8\nvalue = 6.75'),
#  Text(0.5705263157894737, 0.34375, 'X[10] <= 10.85\nsquared_error = 0.245\nsamples = 7\nvalue = 6.571'),
#  Text(0.5663157894736842, 0.28125, 'squared_error = 0.0\nsamples = 3\nvalue = 7.0'),
#  Text(0.5747368421052632, 0.28125, 'X[11] <= 450.0\nsquared_error = 0.188\nsamples = 4\nvalue = 6.25'),
#  Text(0.5705263157894737, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.5789473684210527, 0.21875, 'squared_error = 0.0\nsamples = 3\nvalue = 6.0'),
#  Text(0.5789473684210527, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 8.0'),
#  Text(0.5831578947368421, 0.40625, 'squared_error = 0.0\nsamples = 3\nvalue = 6.0'),
#  Text(0.5957894736842105, 0.46875, 'X[11] <= 1546.5\nsquared_error = 0.083\nsamples = 11\nvalue = 7.091'),
#  Text(0.5915789473684211, 0.40625, 'squared_error = 0.0\nsamples = 10\nvalue = 7.0'),
#  Text(0.6, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 8.0'),
#  Text(0.6231578947368421, 0.53125, 'X[10] <= 10.95\nsquared_error = 0.395\nsamples = 18\nvalue = 6.222'),
#  Text(0.6126315789473684, 0.46875, 'X[9] <= 0.7\nsquared_error = 0.222\nsamples = 6\nvalue = 5.667'),
#  Text(0.608421052631579, 0.40625, 'squared_error = 0.0\nsamples = 2\nvalue = 5.0'),
#  Text(0.6168421052631579, 0.40625, 'squared_error = 0.0\nsamples = 4\nvalue = 6.0'),
#  Text(0.6336842105263157, 0.46875, 'X[6] <= 24.5\nsquared_error = 0.25\nsamples = 12\nvalue = 6.5'),
#  Text(0.6252631578947369, 0.40625, 'X[10] <= 11.25\nsquared_error = 0.139\nsamples = 6\nvalue = 6.833'),
#  Text(0.6210526315789474, 0.34375, 'squared_error = 0.0\nsamples = 5\nvalue = 7.0'),
#  Text(0.6294736842105263, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.6421052631578947, 0.40625, 'X[5] <= 21.0\nsquared_error = 0.139\nsamples = 6\nvalue = 6.167'),
#  Text(0.6378947368421053, 0.34375, 'squared_error = 0.0\nsamples = 5\nvalue = 6.0'),
#  Text(0.6463157894736842, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.6547368421052632, 0.59375, 'X[0] <= 8.05\nsquared_error = 0.427\nsamples = 15\nvalue = 5.8'),
#  Text(0.6463157894736842, 0.53125, 'X[10] <= 11.35\nsquared_error = 0.222\nsamples = 6\nvalue = 5.333'),
#  Text(0.6421052631578947, 0.46875, 'squared_error = 0.0\nsamples = 4\nvalue = 5.0'),
#  Text(0.6505263157894737, 0.46875, 'squared_error = 0.0\nsamples = 2\nvalue = 6.0'),
#  Text(0.6631578947368421, 0.53125, 'X[1] <= 0.27\nsquared_error = 0.321\nsamples = 9\nvalue = 6.111'),
#  Text(0.6589473684210526, 0.46875, 'squared_error = 0.0\nsamples = 2\nvalue = 7.0'),
#  Text(0.6673684210526316, 0.46875, 'X[2] <= 0.565\nsquared_error = 0.122\nsamples = 7\nvalue = 5.857'),
#  Text(0.6631578947368421, 0.40625, 'squared_error = 0.0\nsamples = 6\nvalue = 6.0'),
#  Text(0.671578947368421, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.7157894736842105, 0.65625, 'X[4] <= 0.122\nsquared_error = 0.309\nsamples = 55\nvalue = 5.982'),
#  Text(0.7010526315789474, 0.59375, 'X[9] <= 0.79\nsquared_error = 0.234\nsamples = 51\nvalue = 6.039'),
#  Text(0.6926315789473684, 0.53125, 'X[4] <= 0.12\nsquared_error = 0.136\nsamples = 37\nvalue = 6.162'),
#  Text(0.6884210526315789, 0.46875, 'X[3] <= 5.15\nsquared_error = 0.101\nsamples = 35\nvalue = 6.114'),
#  Text(0.68, 0.40625, 'X[10] <= 10.575\nsquared_error = 0.059\nsamples = 32\nvalue = 6.062'),
#  Text(0.6757894736842105, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.6842105263157895, 0.34375, 'X[4] <= 0.067\nsquared_error = 0.031\nsamples = 31\nvalue = 6.032'),
#  Text(0.68, 0.28125, 'X[5] <= 9.5\nsquared_error = 0.139\nsamples = 6\nvalue = 6.167'),
#  Text(0.6757894736842105, 0.21875, 'squared_error = 0.0\nsamples = 4\nvalue = 6.0'),
#  Text(0.6842105263157895, 0.21875, 'X[6] <= 39.5\nsquared_error = 0.25\nsamples = 2\nvalue = 6.5'),
#  Text(0.68, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.6884210526315789, 0.15625, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.6884210526315789, 0.28125, 'squared_error = 0.0\nsamples = 25\nvalue = 6.0'),
#  Text(0.6968421052631579, 0.40625, 'X[9] <= 0.705\nsquared_error = 0.222\nsamples = 3\nvalue = 6.667'),
#  Text(0.6926315789473684, 0.34375, 'squared_error = 0.0\nsamples = 2\nvalue = 7.0'),
#  Text(0.7010526315789474, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.6968421052631579, 0.46875, 'squared_error = 0.0\nsamples = 2\nvalue = 7.0'),
#  Text(0.7094736842105264, 0.53125, 'X[5] <= 14.5\nsquared_error = 0.347\nsamples = 14\nvalue = 5.714'),
#  Text(0.7052631578947368, 0.46875, 'squared_error = 0.0\nsamples = 4\nvalue = 5.0'),
#  Text(0.7136842105263158, 0.46875, 'X[11] <= 322.0\nsquared_error = 0.2\nsamples = 10\nvalue = 6.0'),
#  Text(0.7094736842105264, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.7178947368421053, 0.40625, 'X[1] <= 0.42\nsquared_error = 0.099\nsamples = 9\nvalue = 5.889'),
#  Text(0.7136842105263158, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.7221052631578947, 0.34375, 'squared_error = 0.0\nsamples = 8\nvalue = 6.0'),
#  Text(0.7305263157894737, 0.59375, 'X[9] <= 0.74\nsquared_error = 0.688\nsamples = 4\nvalue = 5.25'),
#  Text(0.7263157894736842, 0.53125, 'X[10] <= 11.1\nsquared_error = 0.25\nsamples = 2\nvalue = 4.5'),
#  Text(0.7221052631578947, 0.46875, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.7305263157894737, 0.46875, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.7347368421052631, 0.53125, 'squared_error = 0.0\nsamples = 2\nvalue = 6.0'),
#  Text(0.7992105263157895, 0.78125, 'X[9] <= 0.685\nsquared_error = 0.551\nsamples = 113\nvalue = 6.513'),
#  Text(0.7547368421052632, 0.71875, 'X[11] <= 242.5\nsquared_error = 0.457\nsamples = 57\nvalue = 6.228'),
#  Text(0.7431578947368421, 0.65625, 'X[4] <= 0.052\nsquared_error = 0.25\nsamples = 2\nvalue = 4.5'),
#  Text(0.7389473684210527, 0.59375, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.7473684210526316, 0.59375, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.7663157894736842, 0.65625, 'X[11] <= 1112.5\nsquared_error = 0.352\nsamples = 55\nvalue = 6.291'),
#  Text(0.7557894736842106, 0.59375, 'X[5] <= 41.25\nsquared_error = 0.307\nsamples = 35\nvalue = 6.486'),
#  Text(0.751578947368421, 0.53125, 'X[0] <= 8.95\nsquared_error = 0.247\nsamples = 34\nvalue = 6.441'),
#  Text(0.7431578947368421, 0.46875, 'X[0] <= 8.25\nsquared_error = 0.236\nsamples = 21\nvalue = 6.619'),
#  Text(0.7389473684210527, 0.40625, 'X[7] <= 0.994\nsquared_error = 0.249\nsamples = 15\nvalue = 6.467'),
#  Text(0.7305263157894737, 0.34375, 'X[1] <= 0.245\nsquared_error = 0.188\nsamples = 8\nvalue = 6.75'),
#  Text(0.7263157894736842, 0.28125, 'squared_error = 0.0\nsamples = 2\nvalue = 6.0'),
#  Text(0.7347368421052631, 0.28125, 'squared_error = 0.0\nsamples = 6\nvalue = 7.0'),
#  Text(0.7473684210526316, 0.34375, 'X[5] <= 19.5\nsquared_error = 0.122\nsamples = 7\nvalue = 6.143'),
#  Text(0.7431578947368421, 0.28125, 'squared_error = 0.0\nsamples = 6\nvalue = 6.0'),
#  Text(0.751578947368421, 0.28125, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.7473684210526316, 0.40625, 'squared_error = 0.0\nsamples = 6\nvalue = 7.0'),
#  Text(0.76, 0.46875, 'X[11] <= 523.5\nsquared_error = 0.13\nsamples = 13\nvalue = 6.154'),
#  Text(0.7557894736842106, 0.40625, 'squared_error = 0.0\nsamples = 2\nvalue = 7.0'),
#  Text(0.7642105263157895, 0.40625, 'squared_error = 0.0\nsamples = 11\nvalue = 6.0'),
#  Text(0.76, 0.53125, 'squared_error = 0.0\nsamples = 1\nvalue = 8.0'),
#  Text(0.7768421052631579, 0.59375, 'X[5] <= 4.5\nsquared_error = 0.247\nsamples = 20\nvalue = 5.95'),
#  Text(0.7726315789473684, 0.53125, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.7810526315789473, 0.53125, 'X[10] <= 11.75\nsquared_error = 0.05\nsamples = 19\nvalue = 6.053'),
#  Text(0.7768421052631579, 0.46875, 'X[1] <= 0.54\nsquared_error = 0.188\nsamples = 4\nvalue = 6.25'),
#  Text(0.7726315789473684, 0.40625, 'squared_error = 0.0\nsamples = 3\nvalue = 6.0'),
#  Text(0.7810526315789473, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.7852631578947369, 0.46875, 'squared_error = 0.0\nsamples = 15\nvalue = 6.0'),
#  Text(0.8436842105263158, 0.71875, 'X[5] <= 21.5\nsquared_error = 0.479\nsamples = 56\nvalue = 6.804'),
#  Text(0.8178947368421052, 0.65625, 'X[11] <= 307.0\nsquared_error = 0.414\nsamples = 41\nvalue = 6.976'),
#  Text(0.8136842105263158, 0.59375, 'squared_error = 0.0\nsamples = 2\nvalue = 8.0'),
#  Text(0.8221052631578948, 0.59375, 'X[7] <= 0.995\nsquared_error = 0.379\nsamples = 39\nvalue = 6.923'),
#  Text(0.8021052631578948, 0.53125, 'X[6] <= 18.0\nsquared_error = 0.139\nsamples = 18\nvalue = 7.167'),
#  Text(0.7936842105263158, 0.46875, 'X[1] <= 0.37\nsquared_error = 0.222\nsamples = 3\nvalue = 7.667'),
#  Text(0.7894736842105263, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.7978947368421052, 0.40625, 'squared_error = 0.0\nsamples = 2\nvalue = 8.0'),
#  Text(0.8105263157894737, 0.46875, 'X[5] <= 18.5\nsquared_error = 0.062\nsamples = 15\nvalue = 7.067'),
#  Text(0.8063157894736842, 0.40625, 'squared_error = 0.0\nsamples = 14\nvalue = 7.0'),
#  Text(0.8147368421052632, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 8.0'),
#  Text(0.8421052631578947, 0.53125, 'X[8] <= 3.36\nsquared_error = 0.49\nsamples = 21\nvalue = 6.714'),
#  Text(0.8315789473684211, 0.46875, 'X[1] <= 0.425\nsquared_error = 0.321\nsamples = 18\nvalue = 6.889'),
#  Text(0.8231578947368421, 0.40625, 'X[5] <= 5.5\nsquared_error = 0.209\nsamples = 14\nvalue = 7.071'),
#  Text(0.8189473684210526, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.8273684210526315, 0.34375, 'X[6] <= 17.5\nsquared_error = 0.13\nsamples = 13\nvalue = 7.154'),
#  Text(0.8231578947368421, 0.28125, 'X[2] <= 0.37\nsquared_error = 0.222\nsamples = 3\nvalue = 7.667'),
#  Text(0.8189473684210526, 0.21875, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.8273684210526315, 0.21875, 'squared_error = 0.0\nsamples = 2\nvalue = 8.0'),
#  Text(0.8315789473684211, 0.28125, 'squared_error = 0.0\nsamples = 10\nvalue = 7.0'),
#  Text(0.84, 0.40625, 'X[5] <= 8.5\nsquared_error = 0.188\nsamples = 4\nvalue = 6.25'),
#  Text(0.8357894736842105, 0.34375, 'squared_error = 0.0\nsamples = 3\nvalue = 6.0'),
#  Text(0.8442105263157895, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.8526315789473684, 0.46875, 'X[11] <= 1065.0\nsquared_error = 0.222\nsamples = 3\nvalue = 5.667'),
#  Text(0.848421052631579, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.8568421052631578, 0.40625, 'squared_error = 0.0\nsamples = 2\nvalue = 6.0'),
#  Text(0.8694736842105263, 0.65625, 'X[10] <= 12.75\nsquared_error = 0.356\nsamples = 15\nvalue = 6.333'),
#  Text(0.8610526315789474, 0.59375, 'X[3] <= 1.9\nsquared_error = 0.24\nsamples = 10\nvalue = 6.6'),
#  Text(0.8568421052631578, 0.53125, 'squared_error = 0.0\nsamples = 2\nvalue = 6.0'),
#  Text(0.8652631578947368, 0.53125, 'X[5] <= 23.5\nsquared_error = 0.188\nsamples = 8\nvalue = 6.75'),
#  Text(0.8610526315789474, 0.46875, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.8694736842105263, 0.46875, 'X[7] <= 0.996\nsquared_error = 0.122\nsamples = 7\nvalue = 6.857'),
#  Text(0.8652631578947368, 0.40625, 'squared_error = 0.0\nsamples = 5\nvalue = 7.0'),
#  Text(0.8736842105263158, 0.40625, 'X[4] <= 0.073\nsquared_error = 0.25\nsamples = 2\nvalue = 6.5'),
#  Text(0.8694736842105263, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.8778947368421053, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.8778947368421053, 0.59375, 'X[5] <= 24.0\nsquared_error = 0.16\nsamples = 5\nvalue = 5.8'),
#  Text(0.8736842105263158, 0.53125, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.8821052631578947, 0.53125, 'squared_error = 0.0\nsamples = 4\nvalue = 6.0'),
#  Text(0.9515789473684211, 0.84375, 'X[1] <= 0.87\nsquared_error = 0.648\nsamples = 84\nvalue = 5.583'),
#  Text(0.9263157894736842, 0.78125, 'X[2] <= 0.665\nsquared_error = 0.478\nsamples = 71\nvalue = 5.732'),
#  Text(0.9221052631578948, 0.71875, 'X[5] <= 11.5\nsquared_error = 0.41\nsamples = 70\nvalue = 5.7'),
#  Text(0.9031578947368422, 0.65625, 'X[11] <= 990.0\nsquared_error = 0.307\nsamples = 27\nvalue = 5.37'),
#  Text(0.8947368421052632, 0.59375, 'X[9] <= 0.755\nsquared_error = 0.225\nsamples = 13\nvalue = 5.077'),
#  Text(0.8905263157894737, 0.53125, 'X[1] <= 0.812\nsquared_error = 0.083\nsamples = 11\nvalue = 4.909'),
#  Text(0.8863157894736842, 0.46875, 'squared_error = 0.0\nsamples = 10\nvalue = 5.0'),
#  Text(0.8947368421052632, 0.46875, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.8989473684210526, 0.53125, 'squared_error = 0.0\nsamples = 2\nvalue = 6.0'),
#  Text(0.911578947368421, 0.59375, 'X[2] <= 0.04\nsquared_error = 0.23\nsamples = 14\nvalue = 5.643'),
#  Text(0.9073684210526316, 0.53125, 'squared_error = 0.0\nsamples = 6\nvalue = 6.0'),
#  Text(0.9157894736842105, 0.53125, 'X[8] <= 3.355\nsquared_error = 0.234\nsamples = 8\nvalue = 5.375'),
#  Text(0.911578947368421, 0.46875, 'squared_error = 0.0\nsamples = 3\nvalue = 6.0'),
#  Text(0.92, 0.46875, 'squared_error = 0.0\nsamples = 5\nvalue = 5.0'),
#  Text(0.9410526315789474, 0.65625, 'X[7] <= 0.992\nsquared_error = 0.363\nsamples = 43\nvalue = 5.907'),
#  Text(0.9368421052631579, 0.59375, 'squared_error = 0.0\nsamples = 1\nvalue = 8.0'),
#  Text(0.9452631578947368, 0.59375, 'X[11] <= 974.5\nsquared_error = 0.265\nsamples = 42\nvalue = 5.857'),
#  Text(0.9326315789473684, 0.53125, 'X[8] <= 3.36\nsquared_error = 0.152\nsamples = 16\nvalue = 6.188'),
#  Text(0.9284210526315789, 0.46875, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.9368421052631579, 0.46875, 'X[1] <= 0.812\nsquared_error = 0.116\nsamples = 15\nvalue = 6.133'),
#  Text(0.9326315789473684, 0.40625, 'X[8] <= 3.57\nsquared_error = 0.066\nsamples = 14\nvalue = 6.071'),
#  Text(0.9284210526315789, 0.34375, 'squared_error = 0.0\nsamples = 13\nvalue = 6.0'),
#  Text(0.9368421052631579, 0.34375, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.9410526315789474, 0.40625, 'squared_error = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(0.9578947368421052, 0.53125, 'X[9] <= 0.555\nsquared_error = 0.226\nsamples = 26\nvalue = 5.654'),
#  Text(0.9536842105263158, 0.46875, 'squared_error = 0.0\nsamples = 4\nvalue = 5.0'),
#  Text(0.9621052631578947, 0.46875, 'X[0] <= 7.4\nsquared_error = 0.176\nsamples = 22\nvalue = 5.773'),
#  Text(0.9494736842105264, 0.40625, 'X[10] <= 11.95\nsquared_error = 0.059\nsamples = 16\nvalue = 5.938'),
#  Text(0.9452631578947368, 0.34375, 'squared_error = 0.0\nsamples = 13\nvalue = 6.0'),
#  Text(0.9536842105263158, 0.34375, 'X[1] <= 0.642\nsquared_error = 0.222\nsamples = 3\nvalue = 5.667'),
#  Text(0.9494736842105264, 0.28125, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.9578947368421052, 0.28125, 'squared_error = 0.0\nsamples = 2\nvalue = 6.0'),
#  Text(0.9747368421052631, 0.40625, 'X[5] <= 26.0\nsquared_error = 0.222\nsamples = 6\nvalue = 5.333'),
#  Text(0.9705263157894737, 0.34375, 'X[7] <= 0.996\nsquared_error = 0.222\nsamples = 3\nvalue = 5.667'),
#  Text(0.9663157894736842, 0.28125, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.9747368421052631, 0.28125, 'squared_error = 0.0\nsamples = 2\nvalue = 6.0'),
#  Text(0.9789473684210527, 0.34375, 'squared_error = 0.0\nsamples = 3\nvalue = 5.0'),
#  Text(0.9305263157894736, 0.71875, 'squared_error = 0.0\nsamples = 1\nvalue = 8.0'),
#  Text(0.9768421052631578, 0.78125, 'X[3] <= 2.05\nsquared_error = 0.793\nsamples = 13\nvalue = 4.769'),
#  Text(0.9663157894736842, 0.71875, 'X[1] <= 1.0\nsquared_error = 0.438\nsamples = 8\nvalue = 5.25'),
#  Text(0.9578947368421052, 0.65625, 'X[2] <= 0.135\nsquared_error = 0.188\nsamples = 4\nvalue = 5.75'),
#  Text(0.9536842105263158, 0.59375, 'squared_error = 0.0\nsamples = 3\nvalue = 6.0'),
#  Text(0.9621052631578947, 0.59375, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.9747368421052631, 0.65625, 'X[4] <= 0.082\nsquared_error = 0.188\nsamples = 4\nvalue = 4.75'),
#  Text(0.9705263157894737, 0.59375, 'squared_error = 0.0\nsamples = 3\nvalue = 5.0'),
#  Text(0.9789473684210527, 0.59375, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.9873684210526316, 0.71875, 'X[2] <= 0.015\nsquared_error = 0.4\nsamples = 5\nvalue = 4.0'),
#  Text(0.9831578947368421, 0.65625, 'squared_error = 0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.991578947368421, 0.65625, 'X[2] <= 0.255\nsquared_error = 0.188\nsamples = 4\nvalue = 4.25'),
#  Text(0.9873684210526316, 0.59375, 'squared_error = 0.0\nsamples = 3\nvalue = 4.0'),
#  Text(0.9957894736842106, 0.59375, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0')]

# %% [markdown]
# ## SVM Model:

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### Create and Train the SVM Model

# %%
svm_regressor = SVR(kernel='linear', C=1.0)  # You can choose a different kernel if needed
svm_regressor.fit(X_train, y_train)
# Out:
# SVR(kernel='linear')

# %%
y_pred = svm_regressor.predict(X_test)

# %%
svm_mse = mean_squared_error(y_test, y_pred)
svm_r2 = r2_score(y_test, y_pred)


print("SVM Regressor Metrics:")
print("Mean Squared Error:", svm_mse)
print("R-squared:", svm_r2)
# Out:
# SVM Regressor Metrics:
# Mean Squared Error: 0.4274210148097294
# R-squared: 0.3639231255480565

# %%
# Compare models and select the best one based on MSE and R-squared
models = [ 'SVM Regressor', 'Decision Tree Regressor']
mse_scores = [ svm_mse, dt_mse]
r2_scores = [svm_r2, dt_r2]

best_model_index = mse_scores.index(min(mse_scores))
best_model_name = models[best_model_index]

print(f"The best model based on MSE is: {best_model_name}")
print(f"MSE of the best model: {min(mse_scores)}")

best_model_index = r2_scores.index(max(r2_scores))
best_model_name = models[best_model_index]

print(f"The best model based on R-squared is: {best_model_name}")
print(f"R-squared of the best model: {max(r2_scores)}")
# Out:
# The best model based on MSE is: SVM Regressor
# MSE of the best model: 0.4274210148097294
# The best model based on R-squared is: SVM Regressor
# R-squared of the best model: 0.3639231255480565
